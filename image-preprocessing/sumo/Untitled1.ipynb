# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('bulls.jpg')
xdata = np.linspace(0,len(img)*len(img[0]),num=len(img)*len(img[0]))
ydata = np.linspace(0,len(img[0])*len(img),num=len(img[0])*len(img))
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(hsv), plt.title('hsv image'), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1294321d0>, Text(0.5,1,'hsv image'), None)

# %%
#hist = cv2.calcHist([hsv], [0, 1], None, [180, 256], [0, 180, 0, 256])
xbins = 16
ybins = 16
H, xedges, yedges = np.histogram2d(xdata, ydata, bins=(xbins,ybins))

# %%
print(np.amax(hist))
# Out:
# 541829.0

# %%
plt.imshow(hist,interpolation = 'nearest')
plt.show()

# %%
getbin2d = 5
xedge_i = getbin2d % xbins
yedge_i = int(getbin2d / xbins)

# %%
for x, y in zip(xdata, ydata):
    # x and y left edges
    if x >= xedges[xedge_i] and y >= yedges[yedge_i]:
        #x right edge
        if xedge_i == xbins-1 or x < xedges[xedge_i + 1]:
            #y right edge
            if yedge_i == ybins-1 or y < yedges[yedge_i + 1]:
                print 'found:', x, y

# %%
# !git pull
# Out:
# remote: Counting objects: 8, done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 2), reused 8 (delta 2), pack-reused 0
# Unpacking objects: 100% (8/8), done.
# From https://github.com/haroonchoudery/player-speed
#    3d4d4ff..43d0f10  master     -> origin/master
# Updating 3d4d4ff..43d0f10
# Fast-forward
#  .gitignore                                         |   1 +
#  .../haroon/haroon-image-masking.ipynb              |  17 --
#  object-detection/coco                              |   1 +
#  object-detection/maskrcnn                          |   1 +
#  object-detection/object-detection.ipynb            | 250 +++++++++++++++++++++
#  5 files changed, 253 insertions(+), 17 deletions(-)
#  create mode 160000 object-detection/coco
#  create mode 160000 object-detection/maskrcnn
#  create mode 100644 object-detection/object-detection.ipynb
